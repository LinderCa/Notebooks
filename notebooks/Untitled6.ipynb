# %%
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt

# %%
# Generate some example data
x = np.array([1, 2, 3, 4, 5])
y = np.array([2.5, 3.5, 4.0, 4.5, 5.0])

# %%
# Perform linear regression
slope, intercept, r_value, p_value, std_err = linregress(x, y)

# Output the results
print(f"Slope: {slope}")
print(f"Intercept: {intercept}")
print(f"R-squared: {r_value**2}")
print(f"P-value: {p_value}")
print(f"Standard error: {std_err}")
# Out:
# Slope: 0.6000000000000001
# Intercept: 2.0999999999999996
# R-squared: 0.972972972972973
# P-value: 0.001901274660196368
# Standard error: 0.057735026918962526

# %%
# Plot the data and regression line
plt.scatter(x, y, label='Data points')
plt.plot(x, intercept + slope * x, color='red', label='Linear regression line')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression Example')
plt.show()
